# %%
def load_file(filename):
    with open(filename, encoding="utf-8") as f:
        return f.read().lower()

# %%
dataset = load_file("data.txt")

# %%
def transitionTable(data, k=4):
    """Here data is string and k is an integer denoting the value of length of substring"""
    T = {}
    # Some computation
    for i in range(len(data)-k):
        X = data[i:i+k] # Substring extraction
        Y = data[i+k] # Next character of Substring
        if T.get(X) is None: # If Substring is not present
            T[X] = {}
            T[X][Y] = 1
        elif T[X].get(Y) is None: # if next character of substring is not present
            T[X][Y] = 1
        else: # increasing the frequency
            T[X][Y] += 1
    return T

# %%
tranisitiondata = transitionTable("hello hello hy helli")
print(tranisitiondata)
# Out:
# {'hell': {'o': 2, 'i': 1}, 'ello': {' ': 2}, 'llo ': {'h': 2}, 'lo h': {'e': 1, 'y': 1}, 'o he': {'l': 1}, ' hel': {'l': 2}, 'o hy': {' ': 1}, ' hy ': {'h': 1}, 'hy h': {'e': 1}, 'y he': {'l': 1}}

# %%
sum(tranisitiondata["hell"].values())
# Out:
# 3

# %%
def probabilityTransition(T):
    for kx in T.keys():
        norm_factor = sum(T[kx].values()) # extract the denominator
        for val in T[kx].keys():
            T[kx][val] = T[kx][val]/norm_factor #divide to get the probability

# %%
probabilityTransition(tranisitiondata)

# %%
tranisitiondata
# Out:
# {'hell': {'o': 0.6666666666666666, 'i': 0.3333333333333333},
#  'ello': {' ': 1.0},
#  'llo ': {'h': 1.0},
#  'lo h': {'e': 0.5, 'y': 0.5},
#  'o he': {'l': 1.0},
#  ' hel': {'l': 1.0},
#  'o hy': {' ': 1.0},
#  ' hy ': {'h': 1.0},
#  'hy h': {'e': 1.0},
#  'y he': {'l': 1.0}}

# %% [markdown]
# ## prediction

# %%
import numpy as np

fruits = ["Mango", "Banana", "Apple"]
probab = [0.7, 0.2, 0.1]

for i in range(10):
    print(np.random.choice(fruits, p=probab))
# Out:
# Mango
# Banana
# Mango
# Mango
# Mango
# Banana
# Mango
# Mango
# Apple
# Apple

# %%
def predict(string, T):
    if T.get(string) is None:
        return " "
    keys = list(T[string].keys())
    probability = list(T[string].values())
    
    return np.random.choice(keys, p=probability)

# %%
for i in range(10):
    print(predict("hell", tranisitiondata))
# Out:
# i
# i
# o
# o
# o
# i
# o
# o
# o
# o

# %%
tranisitiondata["hell"].values()
# Out:
# dict_values([0.6666666666666666, 0.3333333333333333])

# %%
transit_dataset = transitionTable(dataset)
print(transit_dataset)
# Out:
# {'कौन ': {'ब': 3}, 'ौन ब': {'ो': 3}, 'न बो': {'ल': 3}, ' बोल': {'ा': 3}, 'बोला': {' ': 1, ',': 1, '\n': 1}, 'ोला ': {'म': 1}, 'ला म': {'ु': 1}, 'ा मु': {'झ': 1}, ' मुझ': {'स': 1}, 'मुझस': {'े': 1}, 'ुझसे': {' ': 1}, 'झसे ': {'न': 1}, 'से न': {' ': 1}, 'े न ': {'ह': 1, 'म': 1}, ' न ह': {'ो': 1}, 'न हो': {' ': 1}, ' हो ': {'प': 1}, 'हो प': {'ा': 1}, 'ो पा': {'य': 1}, ' पाय': {'े': 2}, 'पाये': {'ग': 2}, 'ायेग': {'ा': 5}, 'येगा': {'\n': 5}, 'ेगा\n': {'क': 1, 'य': 1, 'ज': 1, 'ऐ': 1, 'अ': 1}, 'गा\nक': {'ौ': 1, 'ल': 1}, 'ा\nकौ': {'न': 1}, '\nकौन': {' ': 1}, 'ोला,': {' ': 1}, 'ला, ': {'क': 1}, 'ा, क': {'ौ': 1}, ', कौ': {'न': 1}, ' कौन': {' ': 1}, 'ोला\n': {'अ': 1}, 'ला\nअ': {'प': 1}, 'ा\nअप': {'न': 16}, '\nअपन': {'ा': 16}, 'अपना': {' ': 19}, 'पना ': {'t': 19}, 'ना t': {'i': 19}, 'ा ti': {'m': 19}, ' tim': {'e': 19}, 'time': {' ': 19}, 'ime ': {'आ': 19}, 'me आ': {'ए': 19}, 'e आए': {'ग': 19}, ' आएग': {'ा': 19}, 'आएगा': {'\n': 18, ' ': 2}, 'एगा\n': {'उ': 1, 'आ': 1, 'म': 1, 'ज': 1, 'त': 6, 'अ': 15, 'क': 1}, 'गा\nउ': {'ठ': 1}, 'ा\nउठ': {' ': 1}, '\nउठ ': {'ज': 2}, 'उठ ज': {'ा': 2}, 'ठ जा': {' ': 2}, ' जा ': {'अ': 2}, 'जा अ': {'प': 1, 'ब': 1}, 'ा अप': {'न': 2}, ' अपन': {'ी': 1, 'ा': 3}, 'अपनी': {' ': 1}, 'पनी ': {'र': 1}, 'नी र': {'ा': 1, 'ह': 1}, 'ी रा': {'ख': 1}, ' राख': {' ': 1}, 'राख ': {'स': 1}, 'ाख स': {'े': 1}, 'ख से': {' ': 1}, ' से ': {'त': 1, 'ज': 1, 'म': 1}, 'से त': {'ू': 2}, 'े तू': {'\n': 1, ' ': 1}, ' तू\n': {'उ': 1}, 'तू\nउ': {'ठ': 1}, 'ू\nउठ': {' ': 1}, 'ा अब': {' ': 2}, ' अब ': {'त': 1, 'ज': 1, 'आ': 1, 'ल': 1}, 'अब त': {'ल': 1}, 'ब तल': {'ा': 1}, ' तला': {'श': 1}, 'तलाश': {' ': 1}, 'लाश ': {'म': 1}, 'ाश म': {'े': 1}, 'श मे': {'ं': 1}, ' में': {'\n': 3, ' ': 2}, 'में\n': {'प': 1, 'ह': 1, 'क': 1}, 'ें\nप': {'र': 1}, 'ं\nपर': {'व': 1}, '\nपरव': {'ा': 1}, 'परवा': {'ज़': 1, 'न': 1}, 'रवाज़': {' ': 1}, 'वाज़ ': {'द': 1}, 'ाज़ द': {'े': 1}, 'ज़ दे': {'ख': 1}, ' देख': {' ': 1}, 'देख ': {'प': 1}, 'ेख प': {'र': 1}, 'ख पर': {'व': 1}, ' परव': {'ा': 1}, 'रवान': {'े': 1}, 'वाने': {' ': 1}, 'ाने ': {'क': 1}, 'ने क': {'ी': 2}, 'े की': {'\n': 1, ' ': 1}, ' की\n': {'अ': 3, 'म': 1, 'ज': 1}, 'की\nअ': {'स': 1, 'द': 1, 'ब': 1}, 'ी\nअस': {'म': 1}, '\nअसम': {'ा': 1}, 'असमा': {'न': 1}, 'समान': {' ': 1}, 'मान ': {'भ': 1}, 'ान भ': {'ी': 1}, 'न भी': {' ': 1}, ' भी ': {'स': 2, 'ल': 1}, 'भी स': {'र': 1, 'त': 1}, 'ी सर': {' ': 1}, ' सर ': {'उ': 1, 'प': 1}, 'सर उ': {'ठ': 1}, 'र उठ': {'ा': 1}, ' उठा': {'ए': 1}, 'उठाए': {'ग': 1}, 'ठाएग': {'ा': 1}, 'ाएगा': {'\n': 8, ' ': 1}, 'गा\nआ': {'ए': 1}, 'ा\nआए': {'ग': 1}, '\nआएग': {'ा': 1}, 'एगा ': {'अ': 1, 'न': 2}, 'गा अ': {'प': 1}, 'गा\nम': {'े': 1}, 'ा\nमे': {'र': 2}, '\nमेर': {'े': 1, 'ी': 1}, 'मेरे': {' ': 1}, 'ेरे ': {'ज': 1, 'भ': 1}, 'रे ज': {'ै': 1}, 'े जै': {'स': 1}, ' जैस': {'ा': 2}, 'जैसा': {' ': 2}, 'ैसा ': {'श': 1, 'क': 1}, 'सा श': {'ा': 1}, 'ा शा': {'ण': 1}, ' शाण': {'ा': 1}, 'शाणा': {' ': 1}, 'ाणा ': {'ल': 1}, 'णा ल': {'ा': 1}, 'ा ला': {'ल': 1}, ' लाल': {'ा': 1, 'च': 1}, 'लाला': {'\n': 1}, 'ाला\n': {'त': 1, 'म': 1}, 'ला\nत': {'ु': 1}, 'ा\nतु': {'झ': 1}, '\nतुझ': {'े': 1}, 'तुझे': {' ': 1}, 'ुझे ': {'न': 1}, 'झे न': {' ': 1}, ' न म': {'ि': 1}, 'न मि': {'ल': 1}, ' मिल': {' ': 1, 'ा': 1}, 'मिल ': {'प': 1}, 'िल प': {'ा': 1}, 'ल पा': {'य': 1}, 'गा\nय': {'े': 1}, 'ा\nये': {' ': 1}, '\nये ': {'श': 1}, 'ये श': {'ब': 1}, 'े शब': {'्': 1}, ' शब्': {'द': 1}, 'शब्द': {'ो': 1}, 'ब्दो': {'ं': 1}, '्दों': {' ': 1}, 'दों ': {'क': 1}, 'ों क': {'ा': 1}, 'ं का': {' ': 1}, ' का ': {'ज': 1, 'ह': 1}, 'का ज': {'्': 1}, 'ा ज्': {'व': 1}, ' ज्व': {'ा': 1}, 'ज्वा': {'ल': 1}, '्वाल': {'ा': 1}, 'वाला': {'\n': 1}, 'ला\nम': {'े': 1}, 'मेरी': {' ': 1}, 'ेरी ': {'ब': 1}, 'री ब': {'े': 1}, 'ी बे': {'ड़': 1}, ' बेड़': {'ि': 1}, 'बेड़ि': {'य': 1}, 'ेड़िय': {'ा': 1}, 'ड़िया': {'ँ': 1}, 'ियाँ': {' ': 1}, 'याँ ': {'प': 1}, 'ाँ प': {'ि': 1, 'र': 1}, 'ँ पि': {'घ': 1}, ' पिघ': {'ल': 1}, 'पिघल': {'ा': 1}, 'िघला': {'य': 1}, 'घलाय': {'े': 1}, 'लाये': {'ग': 1}, 'गा\nज': {'ि': 2}, 'ा\nजि': {'त': 1, 'ं': 1}, '\nजित': {'न': 2}, 'जितन': {'ा': 1, 'ी': 1}, 'ितना' ...

# %%
probabilityTransition(transit_dataset)

# %%
print(transit_dataset)
# Out:
# {'कौन ': {'ब': 1.0}, 'ौन ब': {'ो': 1.0}, 'न बो': {'ल': 1.0}, ' बोल': {'ा': 1.0}, 'बोला': {' ': 0.3333333333333333, ',': 0.3333333333333333, '\n': 0.3333333333333333}, 'ोला ': {'म': 1.0}, 'ला म': {'ु': 1.0}, 'ा मु': {'झ': 1.0}, ' मुझ': {'स': 1.0}, 'मुझस': {'े': 1.0}, 'ुझसे': {' ': 1.0}, 'झसे ': {'न': 1.0}, 'से न': {' ': 1.0}, 'े न ': {'ह': 0.5, 'म': 0.5}, ' न ह': {'ो': 1.0}, 'न हो': {' ': 1.0}, ' हो ': {'प': 1.0}, 'हो प': {'ा': 1.0}, 'ो पा': {'य': 1.0}, ' पाय': {'े': 1.0}, 'पाये': {'ग': 1.0}, 'ायेग': {'ा': 1.0}, 'येगा': {'\n': 1.0}, 'ेगा\n': {'क': 0.2, 'य': 0.2, 'ज': 0.2, 'ऐ': 0.2, 'अ': 0.2}, 'गा\nक': {'ौ': 0.5, 'ल': 0.5}, 'ा\nकौ': {'न': 1.0}, '\nकौन': {' ': 1.0}, 'ोला,': {' ': 1.0}, 'ला, ': {'क': 1.0}, 'ा, क': {'ौ': 1.0}, ', कौ': {'न': 1.0}, ' कौन': {' ': 1.0}, 'ोला\n': {'अ': 1.0}, 'ला\nअ': {'प': 1.0}, 'ा\nअप': {'न': 1.0}, '\nअपन': {'ा': 1.0}, 'अपना': {' ': 1.0}, 'पना ': {'t': 1.0}, 'ना t': {'i': 1.0}, 'ा ti': {'m': 1.0}, ' tim': {'e': 1.0}, 'time': {' ': 1.0}, 'ime ': {'आ': 1.0}, 'me आ': {'ए': 1.0}, 'e आए': {'ग': 1.0}, ' आएग': {'ा': 1.0}, 'आएगा': {'\n': 0.9, ' ': 0.1}, 'एगा\n': {'उ': 0.038461538461538464, 'आ': 0.038461538461538464, 'म': 0.038461538461538464, 'ज': 0.038461538461538464, 'त': 0.23076923076923078, 'अ': 0.5769230769230769, 'क': 0.038461538461538464}, 'गा\nउ': {'ठ': 1.0}, 'ा\nउठ': {' ': 1.0}, '\nउठ ': {'ज': 1.0}, 'उठ ज': {'ा': 1.0}, 'ठ जा': {' ': 1.0}, ' जा ': {'अ': 1.0}, 'जा अ': {'प': 0.5, 'ब': 0.5}, 'ा अप': {'न': 1.0}, ' अपन': {'ी': 0.25, 'ा': 0.75}, 'अपनी': {' ': 1.0}, 'पनी ': {'र': 1.0}, 'नी र': {'ा': 0.5, 'ह': 0.5}, 'ी रा': {'ख': 1.0}, ' राख': {' ': 1.0}, 'राख ': {'स': 1.0}, 'ाख स': {'े': 1.0}, 'ख से': {' ': 1.0}, ' से ': {'त': 0.3333333333333333, 'ज': 0.3333333333333333, 'म': 0.3333333333333333}, 'से त': {'ू': 1.0}, 'े तू': {'\n': 0.5, ' ': 0.5}, ' तू\n': {'उ': 1.0}, 'तू\nउ': {'ठ': 1.0}, 'ू\nउठ': {' ': 1.0}, 'ा अब': {' ': 1.0}, ' अब ': {'त': 0.25, 'ज': 0.25, 'आ': 0.25, 'ल': 0.25}, 'अब त': {'ल': 1.0}, 'ब तल': {'ा': 1.0}, ' तला': {'श': 1.0}, 'तलाश': {' ': 1.0}, 'लाश ': {'म': 1.0}, 'ाश म': {'े': 1.0}, 'श मे': {'ं': 1.0}, ' में': {'\n': 0.6, ' ': 0.4}, 'में\n': {'प': 0.3333333333333333, 'ह': 0.3333333333333333, 'क': 0.3333333333333333}, 'ें\nप': {'र': 1.0}, 'ं\nपर': {'व': 1.0}, '\nपरव': {'ा': 1.0}, 'परवा': {'ज़': 0.5, 'न': 0.5}, 'रवाज़': {' ': 1.0}, 'वाज़ ': {'द': 1.0}, 'ाज़ द': {'े': 1.0}, 'ज़ दे': {'ख': 1.0}, ' देख': {' ': 1.0}, 'देख ': {'प': 1.0}, 'ेख प': {'र': 1.0}, 'ख पर': {'व': 1.0}, ' परव': {'ा': 1.0}, 'रवान': {'े': 1.0}, 'वाने': {' ': 1.0}, 'ाने ': {'क': 1.0}, 'ने क': {'ी': 1.0}, 'े की': {'\n': 0.5, ' ': 0.5}, ' की\n': {'अ': 0.6, 'म': 0.2, 'ज': 0.2}, 'की\nअ': {'स': 0.3333333333333333, 'द': 0.3333333333333333, 'ब': 0.3333333333333333}, 'ी\nअस': {'म': 1.0}, '\nअसम': {'ा': 1.0}, 'असमा': {'न': 1.0}, 'समान': {' ': 1.0}, 'मान ': {'भ': 1.0}, 'ान भ': {'ी': 1.0}, 'न भी': {' ': 1.0}, ' भी ': {'स': 0.6666666666666666, 'ल': 0.3333333333333333}, 'भी स': {'र': 0.5, 'त': 0.5}, 'ी सर': {' ': 1.0}, ' सर ': {'उ': 0.5, 'प': 0.5}, 'सर उ': {'ठ': 1.0}, 'र उठ': {'ा': 1.0}, ' उठा': {'ए': 1.0}, 'उठाए': {'ग': 1.0}, 'ठाएग': {'ा': 1.0}, 'ाएगा': {'\n': 0.8888888888888888, ' ': 0.1111111111111111}, 'गा\nआ': {'ए': 1.0}, 'ा\nआए': {'ग': 1.0}, '\nआएग': {'ा': 1.0}, 'एगा ': {'अ': 0.3333333333333333, 'न': 0.6666666666666666}, 'गा अ': {'प': 1.0}, 'गा\nम': {'े': 1.0}, 'ा\nमे': {'र': 1.0}, '\nमेर': {'े': 0.5, 'ी': 0.5}, 'मेरे': {' ': 1.0}, 'ेरे ': {'ज': 0.5, 'भ': 0.5}, 'रे ज': {'ै': 1.0}, 'े जै': {'स': 1.0}, ' जैस': {'ा': 1.0}, 'जैसा': {' ': 1.0}, 'ैसा ': {'श': 0.5, 'क': 0.5}, 'सा श': {'ा': 1.0}, 'ा शा': {'ण': 1.0}, ' शाण': {'ा': 1.0}, 'शाणा': {' ': 1.0}, 'ाणा ': {'ल': 1.0}, 'णा ल': {'ा': 1.0}, 'ा ला': {'ल': 1.0}, ' लाल': {'ा': 0.5, 'च': 0.5}, 'लाला': {'\n': 1.0}, 'ाला\n': {'त': 0.5, 'म': 0.5}, 'ला\nत': {'ु': 1.0}, 'ा\nतु': {'झ': 1.0}, '\nतुझ': {'े': 1.0}, 'तुझे': {' ': 1.0}, 'ुझे ': {'न': 1.0}, 'झे न': {' ': 1.0}, ' न म': {'ि': 1.0}, 'न मि': {'ल': 1.0}, ' मिल': {' ': 0.5, 'ा': 0.5}, 'मिल ': {'प': 1.0}, 'िल प': {'ा': 1.0}, 'ल पा': {'य': 1.0}, 'गा\nय ...

# %%
output_statement = "कौन "
for i in range(100):
    predicted_char = predict(output_statement[-4:], transit_dataset)
    output_statement+=predicted_char

print(output_statement)
# Out:
# कौन बोला
# अपना time आएगा अपनी राख से जीने में नहीं
# उतनी ताकत किस्मत में
# परवाज़ देख परवाने की
# असमान भी लड़का
